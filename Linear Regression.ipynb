# %% [markdown]
# ### Bidiretional LSTM for Time Series Forecasting
#
# Libs required:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (10,4)

import numpy as np
import pandas as pd

from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### Reading the data numerically:

# %%
features_train = pd.read_csv('./data/features_train_.csv')
et0_train = pd.read_csv('./data/label_train_.csv')

features_test = pd.read_csv('./data/features_test.csv')
et0_test = pd.read_csv('./data/label_test.csv')

# %%
regr = LinearRegression()

# %%
regr.fit(features_train, et0_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
et0_pred = regr.predict(features_test)

# %%
mean_absolute_error(et0_test, et0_pred)
# Out:
# 2.1920897035997137e-15

# %%
np.sqrt(mean_squared_error(et0_test, et0_pred))
# Out:
# 2.5970040264181126e-15

# %%
et0_pred
# Out:
# array([[  5.57226297],
#        [  4.13913957],
#        [  6.21364161],
#        [  6.45059072],
#        [  5.53483478],
#        [  7.7758166 ],
#        [  6.30902268],
#        [  5.05102728],
#        [  7.32213195],
#        [  8.10374841],
#        [  7.25166816],
#        [  6.24058318],
#        [  7.79376807],
#        [  6.00271952],
#        [  6.07655823],
#        [  7.55448464],
#        [  5.92177983],
#        [  6.1308246 ],
#        [  5.06618533],
#        [  7.64234977],
#        [  6.34272848],
#        [  8.36524697],
#        [  6.14445959],
#        [  6.94943199],
#        [  6.77007253],
#        [  6.47212705],
#        [  6.49108278],
#        [  5.5995151 ],
#        [  6.36094661],
#        [  6.91536948],
#        [  5.25248987],
#        [  7.12650822],
#        [  7.39011029],
#        [  8.61672321],
#        [  6.53093563],
#        [  8.12434657],
#        [  7.78107122],
#        [  6.69579499],
#        [  7.65869985],
#        [  8.544844  ],
# ...
